# %% [markdown]
# <a href="https://colab.research.google.com/github/10Academy-Group-4/Week-4/blob/data_preprocess_mubby/data_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir("/content/drive/MyDrive/SWAHILI/data/train/wav")
os.listdir()
# Out:
# ['SWH-05-20101111',
#  'SWH-05-20101112',
#  'SWH-05-20110327',
#  'SWH-05-20110321',
#  'SWH-15-20101115',
#  'SWH-15-20101117',
#  'SWH-15-20101130',
#  'SWH-15-20101227',
#  'SWH-15-20110124',
#  'SWH-15-20110126',
#  'SWH-15-20110207',
#  'SWH-15-20110224',
#  'SWH-15-20101103',
#  'SWH-15-20101104',
#  'SWH-15-20101109',
#  'SWH-15-20101113',
#  'SWH-15-20110303',
#  'SWH-15-20110310',
#  'SWH-05-20101113',
#  'SWH-05-20101121',
#  'SWH-05-20110215',
#  'SWH-05-20101123',
#  'SWH-05-20110317',
#  'SWH-05-20110123',
#  'SWH-05-20110114',
#  'SWH-05-20110125',
#  'SWH-05-20101110',
#  'SWH-05-20101109',
#  'SWH-05-20101107',
#  'SWH-05-20101106']

# %%
import math, random
import torch
import torchaudio
import numpy as np
from torchaudio import transforms
from IPython.display import Audio
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa
import librosa.display
from scipy.io import wavfile #for audio processing
import warnings
warnings.filterwarnings("ignore")

# %%
# %ls
# Out:
# SWH-05-20101106/  SWH-05-20101123/  SWH-15-20101103/  SWH-15-20110124/
# SWH-05-20101107/  SWH-05-20110114/  SWH-15-20101104/  SWH-15-20110126/
# SWH-05-20101109/  SWH-05-20110123/  SWH-15-20101109/  SWH-15-20110207/
# SWH-05-20101110/  SWH-05-20110125/  SWH-15-20101113/  SWH-15-20110224/
# SWH-05-20101111/  SWH-05-20110215/  SWH-15-20101115/  SWH-15-20110303/
# SWH-05-20101112/  SWH-05-20110317/  SWH-15-20101117/  SWH-15-20110310/
# SWH-05-20101113/  SWH-05-20110321/  SWH-15-20101130/
# SWH-05-20101121/  SWH-05-20110327/  SWH-15-20101227/

# %%
train_audio_path = 'SWH-05-20101106/'
samples, sample_rate = librosa.load(train_audio_path+'SWH-05-20101106_16k-emission_swahili_05h30_-_06h00_tu_20101106_part2.wav')
print(samples)
print(sample_rate)
# Out:
# [ 0.00949342  0.01522155  0.01770687 ... -0.21883075 -0.20150991
#   0.        ]
# 22050

# %%
audio, rate=librosa.load(train_audio_path+'SWH-05-20101106_16k-emission_swahili_05h30_-_06h00_tu_20101106_part2.wav')

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# plotting the wave plot 
plt.figure(figsize=(14,5))
samples, sample_rate = librosa.load(train_audio_path+'SWH-05-20101106_16k-emission_swahili_05h30_-_06h00_tu_20101106_part2.wav')
librosa.display.waveplot(samples, sr=sample_rate)

# %%
#@title Loading another sample

# %%
#@title Generating MetaData

# %%
def tran_loader(filename):
  name_to_text = {}
  with open (filename, encoding="utf-8")as f:
    f.readline()
    for line in f:
      name=line.split("</s>")
      name=name.replace('(', '')
      name=name.replace(')', '')
      name=name.replace('\n','')
      name=name.replace(' ','')
      text=line.split("</s>")[0]
      text=text.replace("<s>","")
      name_to_text[name]=text
    return name_to_text

# %%
tran_loader('/content/drive/MyDrive/Week-4/data/SWAHILI/data/train/text')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-c12699b7b344> in <module>()
# ----> 1 tran_loader('/content/drive/MyDrive/Week-4/data/SWAHILI/data/train/text')
#
# <ipython-input-26-0e3996f5d23c> in tran_loader(filename)
#       5     for line in f:
#       6       name=line.split("</s>")
# ----> 7       name=name.replace('(', '')
#       8       name=name.replace(')', '')
#       9       name=name.replace('\n','')
#
# AttributeError: 'list' object has no attribute 'replace'
